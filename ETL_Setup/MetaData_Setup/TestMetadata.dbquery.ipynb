-- %%
select * from customers;
select * from products;
select * from connectiondetails
select * from eventhubdetails--- where CustomerProductId!=1
select * from customerproduct-- where  CustomerProductId!=1
select * from tableslist --where CustomerProductId!=1
select * from customerwarehousetables where CustomerProductId!=1

select * from pipelinerun

delete from customers where CustomerCode='BOSHOSTest'
---delete from customerproduct where CustomerProductId!=1
