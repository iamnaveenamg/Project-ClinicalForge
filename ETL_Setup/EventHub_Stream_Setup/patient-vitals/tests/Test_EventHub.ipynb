# %%
# 1. import required liberaries
from pyspark import pipelines as dp
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
EH_NAMESPACE = "clinicalforge" #spark.conf.get("eh.namespace")
EH_NAME = "telemetry.patient-vitals" #spark.conf.get("eh.name")
EH_CONN_STR ="Endpoint=sb://clinicalforge.servicebus.windows.net/;SharedAccessKeyName=read-databricks;SharedAccessKey=<REDACTED_SHARED_ACCESS_KEY>" #spark.conf.get("eh.connectionString")

df_raw = (
    spark.readStream
    .format("kafka")
    .options(**KAFKA_OPTIONS)
    .load()
)
